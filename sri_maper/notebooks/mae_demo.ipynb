# %% [markdown]
# This example notebook shows how to run the SRI MAPER code with a Masked Auto Encoder backbone.

# %%
from sri_maper.src.utils import build_hydra_config_notebook, print_config_tree
from sri_maper.src.pretrain import pretrain
from sri_maper.src.train import train
from sri_maper.src.test import test
from sri_maper.src.map import build_map
from torch import set_float32_matmul_precision

set_float32_matmul_precision('medium') # reduces floating point precision for computational efficiency

# %% [markdown]
# First we'll define the "experiment config". An experiment config (short for configuration) defines all changable parameters for the experiment. This includes data parameters (e.g. raster stack to use), model parameters (e.g. backbone architecture), training parameters (e.g. GPU vs CPU training), mapping parameters (e.g. number of monte-carlo samples), and others. [Hydra](https://hydra.cc/) is the open-soure hierarchical experiment configuration library we use to implement our experiment configuration. Please supplement our instructions / guidance with [Hydra's documentation](https://hydra.cc/docs/intro/).
#
# As an example, below we load the config for the national-scale Magmatic Nickel challeng (MaNiAC) presented at Hackathon 2.

# %%
pretrain_cfg = build_hydra_config_notebook(overrides=["experiment=exp_maniac_maevit_pretrain_l22_uscont","trainer=gpu"])
print_config_tree(pretrain_cfg)
# Out:
# CONFIG
# ├── data
# │   └── _target_: sri_maper.src.data.tiff_datamodule.TIFFDataModule
# │       tif_dir: ${paths.data_dir}/H3/MaNiAC
# │       window_size: 33
# │       multiplier: 20
# │       downsample: false
# │       oversample: false
# │       likely_neg_range:
# │       - 0.25
# │       - 0.75
# │       batch_size: 1024
# │       num_workers: 12
# │       pin_memory: false
# │       seed: ${seed}
# │       log_path: ${paths.output_dir}
# │
# ├── model
# │   └── _target_: sri_maper.src.models.cma_module_pretrain_mae.SSCMALitModule
# │       optimizer:
# │         _target_: torch.optim.AdamW
# │         _partial_: true
# │         lr: 0.001
# │         weight_decay: 0.01
# │       scheduler:
# │         _target_: torch.optim.lr_scheduler.ReduceLROnPlateau
# │         _partial_: true
# │         mode: min
# │         factor: 0.1
# │         patience: 10
# │       net:
# │         _target_: sri_maper.src.models.mae_vit.MAE_ViT
# │         image_size: 33
# │         patch_size: 3
# │         input_dim: 14
# │         enc_dim: 256
# │         encoder_layer: 6
# │         encoder_head: 8
# │         dec_dim: 128
# │         output_dim: 14
# │         decoder_layer: 2
# │         decoder_head: 4
# │         mask_ratio: 0.75
# │       compile: false
# │       mc_samples: 100
# │       warmup_epoch: 1
# │
# ├── callbacks
# │   └── model_checkpoint:
# │         _target_: pytorch_lightning.callbacks.ModelCheckpoint
# │         dirpath: ${paths.output_dir}/checkpoints
# │         filename: ssim_{val/ssim:.3f}
# │         monitor: val/ssim
# │         verbose: false
# │         save_last: true
# │         save_top_k: 1
# │         mode: max
# │         auto_insert_metric_name: false
# │         save_weights_only: false
# │         every_n_train_steps: null
# │         train_time_interval: null
# │         every_n_epochs: null
# │         save_on_train_epoch_end: null
# │       early_stopping:
# │         _target_: pytorch_lightning.callbacks.EarlyStopping
# │         monitor: val/ssim_best
# │         min_delta: 0.0
# │         patience: 6
# │         verbose: false
# │         mode: max
# │         strict: true
# │         check_finite: true
# │         stopping_threshold: null
# │         divergence_threshold: null
# │         check_on_train_epoch_end: null
# │       model_summary:
# │         _target_: pytorch_lightning.callbacks.RichModelSummary
# │         max_depth: -1
# │       rich_progress_bar:
# │         _target_: pytorch_lightning.callbacks.RichProgressBar
# │
# ├── logger
# │   └── wandb:
# │         _target_: pytorch_lightning.loggers.wandb.WandbLogger
# │         save_dir: ${paths.output_dir}
# │         offline: false
# │         id: null
# │         anonymous: null
# │         project: ${task_name}
# │         log_model: false
# │         prefix: ''
# │         group: ''
# │         tags: ${tags}
# │         job_type: ''
# │         name: maevit_pretrain_l22_uscont
# │
# ├── trainer
# │   └── _target_: pytorch_lightning.Trainer
# │       default_root_dir: ${paths.output_dir}
# │       min_epochs: 1
# │       max_epochs: 15
# │       accelerator: gpu
# │       devices: 1
# │       precision: 16
# │       val_check_interval: 0.5
# │       deterministic: false
# │       benchmark: true
# │       limit_train_batches: 1.0
# │       limit_val_batches: 1.0
# │       limit_test_batches: 1.0
# │       gradient_clip_val: 1.0
# │
# ├── paths
# │   └── root_dir: ../..
# │       work_dir: ${hydra:runtime.cwd}
# │       data_dir: ${paths.root_dir}/data
# │       log_dir: ${paths.root_dir}/logs
# │       output_dir: ${hydra.run.dir}
# │
# ├── extras
# │   └── ignore_warnings: false
# │       enforce_tags: false
# │       print_config: false
# │
# ├── hydra
# │   └── run:
# │         dir: ${paths.log_dir}/${task_name}/runs/${now:%Y-%m-%d}_${now:%H-%M-%S}
# │       sweep:
# │         dir: ${paths.log_dir}/${task_name}/multiruns/${now:%Y-%m-%d}_${now:%H-%M-%S}
# │         subdir: ${hydra.job.num}
# │       launcher:
# │         _target_: hydra._internal.core_plugins.basic_launcher.BasicLauncher
# │       sweeper:
# │         _target_: hydra._internal.core_plugins.basic_sweeper.BasicSweeper
# │         max_batch_size: null
# │         params: null
# │       help:
# │         app_name: ${hydra.job.name}
# │         header: '${hydra.help.app_name} is powered by Hydra.
# │
# │           '
# │         footer: 'Powered by Hydra (https://hydra.cc)
# │
# │           Use --hydra-help to view Hydra specific help
# │
# │           '
# │         template: '${hydra.help.header}
# │
# │           == Configuration groups ==
# │
# │           Compose your configuration from those groups (group=option)
# │
# │
# │           $APP_CONFIG_GROUPS
# │
# │
# │           == Config ==
# │
# │           Override anything in the config (foo.bar=value)
# │
# │
# │           $CONFIG
# │
# │
# │           ${hydra.help.footer}
# │
# │           '
# │       hydra_help:
# │         template: 'Hydra (${hydra.runtime.version})
# │
# │           See https://hydra.cc for more info.
# │
# │
# │           == Flags ==
# │
# │           $FLAGS_HELP
# │
# │
# │           == Configuration groups ==
# │
# │           Compose your configuration from those groups (For example, append hydra/job_logging=disabled
# │           to command line)
# │
# │
# │           $HYDRA_CONFIG_GROUPS
# │
# │
# │           Use ''--cfg hydra'' to Show the Hydra config.
# │
# │           '
# │         hydra_help: ???
# │       hydra_logging:
# │         version: 1
# │         formatters:
# │           colorlog:
# │             (): colorlog.ColoredFormatter
# │             format: '[%(cyan)s%(asctime)s%(reset)s][%(purple)sHYDRA%(reset)s] %(message)s'
# │         handlers:
# │           console:
# │             class: logging.StreamHandler
# │             formatter: colorlog
# │             stream: ext://sys.stdout
# │         root:
# │           level: INFO
# │           handlers:
# │           - console
# │         disable_existing_loggers: false
# │       job_logging:
# │         version: 1
# │         formatters:
# │           simple:
# │             format: '[%(asctime)s][%(name)s][%(levelname)s] - %(message)s'
# │           colorlog:
# │             (): colorlog.ColoredFormatter
# │             format: '[%(cyan)s%(asctime)s%(reset)s][%(blue)s%(name)s%(reset)s][%(log_color)s%(levelname)s%(reset)
# │               - %(message)s'
# │             log_colors:
# │               DEBUG: purple
# │               INFO: green
# │               WARNING: yellow
# │               ERROR: red
# │               CRITICAL: red
# │         handlers:
# │           console:
# │             class: logging.StreamHandler
# │             formatter: colorlog
# │             stream: ext://sys.stdout
# │           file:
# │             class: logging.FileHandler
# │             formatter: simple
# │             filename: ${paths.output_dir}/${task_name}.log
# │         root:
# │           level: INFO
# │           handlers:
# │           - console
# │           - file
# │         disable_existing_loggers: false
# │       env: {}
# │       mode: null
# │       searchpath: []
# │       callbacks: {}
# │       output_subdir: .hydra
# │       overrides:
# │         hydra: []
# │         task:
# │         - paths.root_dir=../..
# │         - paths.output_dir=${hydra.run.dir}
# │         - extras.print_config=false
# │         - extras.enforce_tags=false
# │         - experiment=exp_maniac_maevit_pretrain_l22_uscont
# │         - trainer=gpu
# │       job:
# │         name: app
# │         chdir: null
# │         override_dirname: experiment=exp_maniac_maevit_pretrain_l22_uscont,extras.enforce_tags=false,extras.print
# │         id: ???
# │         num: ???
# │         config_name: train.yaml
# │         env_set: {}
# │         env_copy: []
# │         config:
# │           override_dirname:
# │             kv_sep: '='
# │             item_sep: ','
# │             exclude_keys: []
# │       runtime:
# │         version: 1.3.2
# │         version_base: '1.3'
# │         cwd: /workspace/sri_maper/notebooks
# │         config_sources:
# │         - path: hydra.conf
# │           schema: pkg
# │           provider: hydra
# │         - path: sri_maper.configs
# │           schema: pkg
# │           provider: main
# │         - path: hydra_plugins.hydra_colorlog.conf
# │           schema: pkg
# │           provider: hydra-colorlog
# │         - path: ''
# │           schema: structured
# │           provider: schema
# │         output_dir: ???
# │         choices:
# │           debug: null
# │           local: default.yaml
# │           hparams_search: null
# │           experiment: exp_maniac_maevit_pretrain_l22_uscont
# │           hydra: default.yaml
# │           extras: default.yaml
# │           paths: default.yaml
# │           trainer: gpu
# │           logger: wandb.yaml
# │           callbacks: default
# │           model: maevit_pretrain
# │           data: default.yaml
# │           preprocess: maniac-natl.yaml
# │           hydra/env: default
# │           hydra/callbacks: null
# │           hydra/job_logging: colorlog
# │           hydra/hydra_logging: colorlog
# │           hydra/hydra_help: default
# │           hydra/help: default
# │           hydra/sweeper: basic
# │           hydra/launcher: basic
# │           hydra/output: default
# │       verbose: false
# │
# ├── task_name
# │   └── cmta3-pretrain-maevit
# ├── tags
# │   └── ['vit', 'cUS', 'mae-vit-pretrain']
# ├── train
# │   └── True
# ├── test
# │   └── True
# ├── tune
# │   └── False
# ├── ckpt_path
# │   └── None
# ├── seed
# │   └── 1234
# └── preprocess
#     └── _target_: sri_maper.src.data.preprocessing.generate_raster_stacks
#         raster_stacks:
#         - raster_stack_path: ${data.tif_dir}/maniac-natl.tif
#           raster_files_path: ${paths.data_dir}/raster_library
#           raster_files:
#           - Geophysics/Seismic/Geophysics_LAB_clipped_dilated.tif
#           - Geophysics/Seismic/Geophysics_LAB_HGM_clipped_dilated.tif
#           - Geophysics/Seismic/Geophysics_LAB_HGM_Worms_clipped_dilated.tif
#           - Geophysics/Seismic/Geophysics_Moho_clipped_dilated.tif
#           - Geophysics/Magnetics/Geophysics_Mag_LOGAnalyticSignal_clipped_dilated.tif
#           - Geophysics/Magnetics/Geophysics_Mag_RTP_Long-Wavelength_HGM_Worms_clipped_dilated.tif
#           - Geophysics/Magnetics/Geophysics_Mag_RTP_clipped_dilated.tif
#           - Geophysics/Magnetics/Geophysics_Mag_RTP_Long-Wavelength_HGM_clipped_dilated.tif
#           - Geophysics/MT/Geophysics_MT2023_9km_clipped_dilated.tif
#           - Geophysics/MT/Geophysics_MT2023_15km_clipped_dilated.tif
#           - Geophysics/MT/Geophysics_MT2023_30km_clipped_dilated.tif
#           - Geophysics/Gravity/Geophysics_Gravity_Isostatic_clipped_dilated.tif
#           - Geophysics/Gravity/Geophysics_Gravity_Bouguer_Up30km_HGM_clipped_dilated.tif
#           - Geophysics/Gravity/Geophysics_Gravity_Bouguer_Up30km_HGM_Worms_clipped_dilated.tif
#           - Labels/magmatic_nickel_sites_v1h2merged_cont_US_clipped_dilated.tif
#           raster_files_types:
#           - float32
#           - float32
#           - float32
#           - float32
#           - float32
#           - float32
#           - float32
#           - float32
#           - float32
#           - float32
#           - float32
#           - float32
#           - float32
#           - float32
#           - bool

# %% [markdown]
# The config above is used to pretrain for the MaNiAC raster stack. In the case of pretraining, the same config can be used for any deposit that uses the same evidence layers in the same order. This possible because the pretrained backbone is used to extract generic features that get finetuned per deposit type (i.e. like a foundation model for that set of evidence layers). Changing the config for another raster stack that exists in our repo (e.g. the set of rasters in the Lawley'22 datacube) is as easy as changing a single paramter. Simply modify the "experiment" variable above with the overrides to a different raster stack [experiment](../configs/experiment/). Current MAE experiment pretrain configs available are:
# * exp_maniac_maevit_pretrain_l22_uscont
# * exp_maevit_pretrain_l22_uscont
#
# Now we can use the generated config file to run the experiment. We pass this config file to the [pretrain task](../src/pretrain.py), which returns metrics and objects created during the run.

# %%
pretrain_metrics, pretrain_objs = pretrain(pretrain_cfg)
# Out:
# Global seed set to 1234
# 100%|██████████| 1/1 [00:00<00:00, 1002.46it/s]
# /opt/conda/lib/python3.10/site-packages/pytorch_lightning/utilities/parsing.py:269: UserWarning: Attribute 'net' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['net'])`.
#   rank_zero_warn(
# wandb: Currently logged in as: adaruna3. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>../../logs/cmta3-pretrain-maevit/runs/2024-03-26_21-04-46/wandb/run-20240326_210448-zbvvtvxa</code>
# Syncing run <strong><a href='https://wandb.ai/adaruna3/cmta3-pretrain-maevit/runs/zbvvtvxa/workspace' target="_blank">maevit_pretrain_l22_uscont</a></strong> to <a href='https://wandb.ai/adaruna3/cmta3-pretrain-maevit' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adaruna3/cmta3-pretrain-maevit' target="_blank">https://wandb.ai/adaruna3/cmta3-pretrain-maevit</a>
#  View run at <a href='https://wandb.ai/adaruna3/cmta3-pretrain-maevit/runs/zbvvtvxa/workspace' target="_blank">https://wandb.ai/adaruna3/cmta3-pretrain-maevit/runs/zbvvtvxa/workspace</a>
# Using 16bit None Automatic Mixed Precision (AMP)
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_test_batches=1.0)` was configured so 100% of the batches will be used..
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# ┏━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓
# ┃     ┃ Name                                  ┃ Type                             ┃ Params ┃
# ┡━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩
# │ 0   │ net                                   │ MAE_ViT                          │  5.3 M │
# │ 1   │ net.encoder                           │ MAE_Encoder                      │  4.8 M │
# │ 2   │ net.encoder.patch_embedding           │ Sequential                       │ 32.5 K │
# │ 3   │ net.encoder.patch_embedding.0         │ Conv2d                           │ 32.5 K │
# │ 4   │ net.encoder.patch_embedding.1         │ Flatten                          │      0 │
# │ 5   │ net.encoder.patch_drop                │ PatchDropLayer                   │      0 │
# │ 6   │ net.encoder.backbone                  │ Sequential                       │  4.7 M │
# │ 7   │ net.encoder.backbone.0                │ Block                            │  788 K │
# │ 8   │ net.encoder.backbone.0.norm1          │ LayerNorm                        │    512 │
# │ 9   │ net.encoder.backbone.0.attn           │ Attention                        │  262 K │
# │ 10  │ net.encoder.backbone.0.attn.qkv       │ Linear                           │  196 K │
# │ 11  │ net.encoder.backbone.0.attn.q_norm    │ Identity                         │      0 │
# │ 12  │ net.encoder.backbone.0.attn.k_norm    │ Identity                         │      0 │
# │ 13  │ net.encoder.backbone.0.attn.attn_drop │ Dropout                          │      0 │
# │ 14  │ net.encoder.backbone.0.attn.proj      │ Linear                           │ 65.8 K │
# │ 15  │ net.encoder.backbone.0.attn.proj_drop │ Dropout                          │      0 │
# │ 16  │ net.encoder.backbone.0.ls1            │ Identity                         │      0 │
# │ 17  │ net.encoder.backbone.0.drop_path1     │ Identity                         │      0 │
# │ 18  │ net.encoder.backbone.0.norm2          │ LayerNorm                        │    512 │
# │ 19  │ net.encoder.backbone.0.mlp            │ Mlp                              │  525 K │
# │ 20  │ net.encoder.backbone.0.mlp.fc1        │ Linear                           │  263 K │
# │ 21  │ net.encoder.backbone.0.mlp.act        │ GELU                             │      0 │
# │ 22  │ net.encoder.backbone.0.mlp.drop1      │ Dropout                          │      0 │
# │ 23  │ net.encoder.backbone.0.mlp.norm       │ Identity                         │      0 │
# │ 24  │ net.encoder.backbone.0.mlp.fc2        │ Linear                           │  262 K │
# │ 25  │ net.encoder.backbone.0.mlp.drop2      │ Dropout                          │      0 │
# │ 26  │ net.encoder.backbone.0.ls2            │ Identity                         │      0 │
# │ 27  │ net.encoder.backbone.0.drop_path2     │ Identity                         │      0 │
# │ 28  │ net.encoder.backbone.1                │ Block                            │  788 K │
# │ 29  │ net.encoder.backbone.1.norm1          │ LayerNorm                        │    512 │
# │ 30  │ net.encoder.backbone.1.attn           │ Attention                        │  262 K │
# │ 31  │ net.encoder.backbone.1.attn.qkv       │ Linear                           │  196 K │
# │ 32  │ net.encoder.backbone.1.attn.q_norm    │ Identity                         │      0 │
# │ 33  │ net.encoder.backbone.1.attn.k_norm    │ Identity                         │      0 │
# │ 34  │ net.encoder.backbone.1.attn.attn_drop │ Dropout                          │      0 │
# │ 35  │ net.encoder.backbone.1.attn.proj      │ Linear                           │ 65.8 K │
# │ 36  │ net.encoder.backbone.1.attn.proj_drop │ Dropout                          │      0 │
# │ 37  │ net.encoder.backbone.1.ls1            │ Identity                         │      0 │
# │ 38  │ net.encoder.backbone.1.drop_path1     │ Identity                         │      0 │
# │ 39  │ net.encoder.backbone.1.norm2          │ LayerNorm                        │    512 │
# │ 40  │ net.encoder.backbone.1.mlp            │ Mlp                              │  525 K │
# │ 41  │ net.encoder.backbone.1.mlp.fc1        │ Linear                           │  263 K │
# │ 42  │ net.encoder.backbone.1.mlp.act        │ GELU                             │      0 │
# │ 43  │ net.encoder.backbone.1.mlp.drop1      │ Dropout                          │      0 │
# │ 44  │ net.encoder.backbone.1.mlp.norm       │ Identity                         │      0 │
# │ 45  │ net.encoder.backbone.1.mlp.fc2        │ Linear                           │  262 K │
# │ 46  │ net.encoder.backbone.1.mlp.drop2      │ Dropout                          │      0 │
# │ 47  │ net.encoder.backbone.1.ls2            │ Identity                         │      0 │
# │ 48  │ net.encoder.backbone.1.drop_path2     │ Identity                         │      0 │
# │ 49  │ net.encoder.backbone.2                │ Block                            │  788 K │
# │ 50  │ net.encoder.backbone.2.norm1          │ LayerNorm                        │    512 │
# │ 51  │ net.encoder.backbone.2.attn           │ Attention                        │  262 K │
# │ 52  │ net.encoder.backbone.2.attn.qkv       │ Linear                           │  196 K │
# │ 53  │ net.encoder.backbone.2.attn.q_norm    │ Identity                         │      0 │
# │ 54  │ net.encoder.backbone.2.attn.k_norm    │ Identity                         │      0 │
# │ 55  │ net.encoder.backbone.2.attn.attn_drop │ Dropout                          │      0 │
# │ 56  │ net.encoder.backbone.2.attn.proj      │ Linear                           │ 65.8 K │
# │ 57  │ net.encoder.backbone.2.attn.proj_drop │ Dropout                          │      0 │
# │ 58  │ net.encoder.backbone.2.ls1            │ Identity                         │      0 │
# │ 59  │ net.encoder.backbone.2.drop_path1     │ Identity                         │      0 │
# │ 60  │ net.encoder.backbone.2.norm2          │ LayerNorm                        │    512 │
# │ 61  │ net.encoder.backbone.2.mlp            │ Mlp                              │  525 K │
# │ 62  │ net.encoder.backbone.2.mlp.fc1        │ Linear                           │  263 K │
# │ 63  │ net.encoder.backbone.2.mlp.act        │ GELU                             │      0 │
# │ 64  │ net.encoder.backbone.2.mlp.drop1      │ Dropout                          │      0 │
# │ 65  │ net.encoder.backbone.2.mlp.norm       │ Identity                         │      0 │
# │ 66  │ net.encoder.backbone.2.mlp.fc2        │ Linear                           │  262 K │
# │ 67  │ net.encoder.backbone.2.mlp.drop2      │ Dropout                          │      0 │
# │ 68  │ net.encoder.backbone.2.ls2            │ Identity                         │      0 │
# │ 69  │ net.encoder.backbone.2.drop_path2     │ Identity                         │      0 │
# │ 70  │ net.encoder.backbone.3                │ Block                            │  788 K │
# │ 71  │ net.encoder.backbone.3.norm1          │ LayerNorm                        │    512 │
# │ 72  │ net.encoder.backbone.3.attn           │ Attention                        │  262 K │
# │ 73  │ net.encoder.backbone.3.attn.qkv       │ Linear                           │  196 K │
# │ 74  │ net.encoder.backbone.3.attn.q_norm    │ Identity                         │      0 │
# │ 75  │ net.encoder.backbone.3.attn.k_norm    │ Identity                         │      0 │
# │ 76  │ net.encoder.backbone.3.attn.attn_drop │ Dropout                          │      0 │
# │ 77  │ net.encoder.backbone.3.attn.proj      │ Linear                           │ 65.8 K │
# │ 78  │ net.encoder.backbone.3.attn.proj_drop │ Dropout                          │      0 │
# │ 79  │ net.encoder.backbone.3.ls1            │ Identity                         │      0 │
# │ 80  │ net.encoder.backbone.3.drop_path1     │ Identity                         │      0 │
# │ 81  │ net.encoder.backbone.3.norm2          │ LayerNorm                        │    512 │
# │ 82  │ net.encoder.backbone.3.mlp            │ Mlp                              │  525 K │
# │ 83  │ net.encoder.backbone.3.mlp.fc1        │ Linear                           │  263 K │
# │ 84  │ net.encoder.backbone.3.mlp.act        │ GELU                             │      0 │
# │ 85  │ net.encoder.backbone.3.mlp.drop1      │ Dropout                          │      0 │
# │ 86  │ net.encoder.backbone.3.mlp.norm       │ Identity                         │      0 │
# │ 87  │ net.encoder.backbone.3.mlp.fc2        │ Linear                           │  262 K │
# │ 88  │ net.encoder.backbone.3.mlp.drop2      │ Dropout                          │      0 │
# │ 89  │ net.encoder.backbone.3.ls2            │ Identity                         │      0 │
# │ 90  │ net.encoder.backbone.3.drop_path2     │ Identity                         │      0 │
# │ 91  │ net.encoder.backbone.4                │ Block                            │  788 K │
# │ 92  │ net.encoder.backbone.4.norm1          │ LayerNorm                        │    512 │
# │ 93  │ net.encoder.backbone.4.attn           │ Attention                        │  262 K │
# │ 94  │ net.encoder.backbone.4.attn.qkv       │ Linear                           │  196 K │
# │ 95  │ net.encoder.backbone.4.attn.q_norm    │ Identity                         │      0 │
# │ 96  │ net.encoder.backbone.4.attn.k_norm    │ Identity                         │      0 │
# │ 97  │ net.encoder.backbone.4.attn.attn_drop │ Dropout                          │      0 │
# │ 98  │ net.encoder.backbone.4.attn.proj      │ Linear                           │ 65.8 K │
# │ 99  │ net.encoder.backbone.4.attn.proj_drop │ Dropout                          │      0 │
# │ 100 │ net.encoder.backbone.4.ls1            │ Identity                         │      0 │
# │ 101 │ net.encoder.backbone.4.drop_path1     │ Identity                         │      0 │
# │ 102 │ net.encoder.backbone.4.norm2          │ LayerNorm                        │    512 │
# │ 103 │ net.encoder.backbone.4.mlp            │ Mlp                              │  525 K │
# │ 104 │ net.encoder.backbone.4.mlp.fc1        │ Linear                           │  263 K │
# │ 105 │ net.encoder.backbone.4.mlp.act        │ GELU                             │      0 │
# │ 106 │ net.encoder.backbone.4.mlp.drop1      │ Dropout                          │      0 │
# │ 107 │ net.encoder.backbone.4.mlp.norm       │ Identity                         │      0 │
# │ 108 │ net.encoder.backbone.4.mlp.fc2        │ Linear                           │  262 K │
# │ 109 │ net.encoder.backbone.4.mlp.drop2      │ Dropout                          │      0 │
# │ 110 │ net.encoder.backbone.4.ls2            │ Identity                         │      0 │
# │ 111 │ net.encoder.backbone.4.drop_path2     │ Identity                         │      0 │
# │ 112 │ net.encoder.backbone.5                │ Block                            │  788 K │
# │ 113 │ net.encoder.backbone.5.norm1          │ LayerNorm                        │    512 │
# │ 114 │ net.encoder.backbone.5.attn           │ Attention                        │  262 K │
# │ 115 │ net.encoder.backbone.5.attn.qkv       │ Linear                           │  196 K │
# │ 116 │ net.encoder.backbone.5.attn.q_norm    │ Identity                         │      0 │
# │ 117 │ net.encoder.backbone.5.attn.k_norm    │ Identity                         │      0 │
# │ 118 │ net.encoder.backbone.5.attn.attn_drop │ Dropout                          │      0 │
# │ 119 │ net.encoder.backbone.5.attn.proj      │ Linear                           │ 65.8 K │
# │ 120 │ net.encoder.backbone.5.attn.proj_drop │ Dropout                          │      0 │
# │ 121 │ net.encoder.backbone.5.ls1            │ Identity                         │      0 │
# │ 122 │ net.encoder.backbone.5.drop_path1     │ Identity                         │      0 │
# │ 123 │ net.encoder.backbone.5.norm2          │ LayerNorm                        │    512 │
# │ 124 │ net.encoder.backbone.5.mlp            │ Mlp                              │  525 K │
# │ 125 │ net.encoder.backbone.5.mlp.fc1        │ Linear                           │  263 K │
# │ 126 │ net.encoder.backbone.5.mlp.act        │ GELU                             │      0 │
# │ 127 │ net.encoder.backbone.5.mlp.drop1      │ Dropout                          │      0 │
# │ 128 │ net.encoder.backbone.5.mlp.norm       │ Identity                         │      0 │
# │ 129 │ net.encoder.backbone.5.mlp.fc2        │ Linear                           │  262 K │
# │ 130 │ net.encoder.backbone.5.mlp.drop2      │ Dropout                          │      0 │
# │ 131 │ net.encoder.backbone.5.ls2            │ Identity                         │      0 │
# │ 132 │ net.encoder.backbone.5.drop_path2     │ Identity                         │      0 │
# │ 133 │ net.encoder.layer_norm                │ LayerNorm                        │    512 │
# │ 134 │ net.decoder                           │ MAE_Decoder                      │  460 K │
# │ 135 │ net.decoder.decoder_proj              │ Linear                           │ 32.9 K │
# │ 136 │ net.decoder.backbone                  │ Sequential                       │  395 K │
# │ 137 │ net.decoder.backbone.0                │ Block                            │  197 K │
# │ 138 │ net.decoder.backbone.0.norm1          │ LayerNorm                        │    256 │
# │ 139 │ net.decoder.backbone.0.attn           │ Attention                        │ 65.7 K │
# │ 140 │ net.decoder.backbone.0.attn.qkv       │ Linear                           │ 49.2 K │
# │ 141 │ net.decoder.backbone.0.attn.q_norm    │ Identity                         │      0 │
# │ 142 │ net.decoder.backbone.0.attn.k_norm    │ Identity                         │      0 │
# │ 143 │ net.decoder.backbone.0.attn.attn_drop │ Dropout                          │      0 │
# │ 144 │ net.decoder.backbone.0.attn.proj      │ Linear                           │ 16.5 K │
# │ 145 │ net.decoder.backbone.0.attn.proj_drop │ Dropout                          │      0 │
# │ 146 │ net.decoder.backbone.0.ls1            │ Identity                         │      0 │
# │ 147 │ net.decoder.backbone.0.drop_path1     │ Identity                         │      0 │
# │ 148 │ net.decoder.backbone.0.norm2          │ LayerNorm                        │    256 │
# │ 149 │ net.decoder.backbone.0.mlp            │ Mlp                              │  131 K │
# │ 150 │ net.decoder.backbone.0.mlp.fc1        │ Linear                           │ 66.0 K │
# │ 151 │ net.decoder.backbone.0.mlp.act        │ GELU                             │      0 │
# │ 152 │ net.decoder.backbone.0.mlp.drop1      │ Dropout                          │      0 │
# │ 153 │ net.decoder.backbone.0.mlp.norm       │ Identity                         │      0 │
# │ 154 │ net.decoder.backbone.0.mlp.fc2        │ Linear                           │ 65.7 K │
# │ 155 │ net.decoder.backbone.0.mlp.drop2      │ Dropout                          │      0 │
# │ 156 │ net.decoder.backbone.0.ls2            │ Identity                         │      0 │
# │ 157 │ net.decoder.backbone.0.drop_path2     │ Identity                         │      0 │
# │ 158 │ net.decoder.backbone.1                │ Block                            │  197 K │
# │ 159 │ net.decoder.backbone.1.norm1          │ LayerNorm                        │    256 │
# │ 160 │ net.decoder.backbone.1.attn           │ Attention                        │ 65.7 K │
# │ 161 │ net.decoder.backbone.1.attn.qkv       │ Linear                           │ 49.2 K │
# │ 162 │ net.decoder.backbone.1.attn.q_norm    │ Identity                         │      0 │
# │ 163 │ net.decoder.backbone.1.attn.k_norm    │ Identity                         │      0 │
# │ 164 │ net.decoder.backbone.1.attn.attn_drop │ Dropout                          │      0 │
# │ 165 │ net.decoder.backbone.1.attn.proj      │ Linear                           │ 16.5 K │
# │ 166 │ net.decoder.backbone.1.attn.proj_drop │ Dropout                          │      0 │
# │ 167 │ net.decoder.backbone.1.ls1            │ Identity                         │      0 │
# │ 168 │ net.decoder.backbone.1.drop_path1     │ Identity                         │      0 │
# │ 169 │ net.decoder.backbone.1.norm2          │ LayerNorm                        │    256 │
# │ 170 │ net.decoder.backbone.1.mlp            │ Mlp                              │  131 K │
# │ 171 │ net.decoder.backbone.1.mlp.fc1        │ Linear                           │ 66.0 K │
# │ 172 │ net.decoder.backbone.1.mlp.act        │ GELU                             │      0 │
# │ 173 │ net.decoder.backbone.1.mlp.drop1      │ Dropout                          │      0 │
# │ 174 │ net.decoder.backbone.1.mlp.norm       │ Identity                         │      0 │
# │ 175 │ net.decoder.backbone.1.mlp.fc2        │ Linear                           │ 65.7 K │
# │ 176 │ net.decoder.backbone.1.mlp.drop2      │ Dropout                          │      0 │
# │ 177 │ net.decoder.backbone.1.ls2            │ Identity                         │      0 │
# │ 178 │ net.decoder.backbone.1.drop_path2     │ Identity                         │      0 │
# │ 179 │ net.decoder.layer_norm                │ LayerNorm                        │    256 │
# │ 180 │ net.decoder.head                      │ Linear                           │ 16.3 K │
# │ 181 │ net.patch2img                         │ Rearrange                        │      0 │
# │ 182 │ val_ssim                              │ StructuralSimilarityIndexMeasure │      0 │
# │ 183 │ val_psnr                              │ PeakSignalNoiseRatio             │      0 │
# │ 184 │ test_ssim                             │ StructuralSimilarityIndexMeasure │      0 │
# │ 185 │ test_psnr                             │ PeakSignalNoiseRatio             │      0 │
# │ 186 │ train_loss                            │ MeanMetric                       │      0 │
# │ 187 │ val_loss                              │ MeanMetric                       │      0 │
# │ 188 │ test_loss                             │ MeanMetric                       │      0 │
# │ 189 │ val_ssim_best                         │ MaxMetric                        │      0 │
# │ 190 │ val_psnr_best                         │ MaxMetric                        │      0 │
# └─────┴───────────────────────────────────────┴──────────────────────────────────┴────────┘
# Trainable params: 5.3 M
# Non-trainable params: 0
# Total params: 5.3 M
# Total estimated model params size (MB): 10
# Output()
# `Trainer.fit` stopped: `max_epochs=15` reached.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /opt/conda/lib/python3.10/site-packages/pytorch_lightning/utilities/parsing.py:269: UserWarning: Attribute 'net' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['net'])`.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Output()
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test/loss         │    0.02311968058347702    │
# │         test/psnr         │     33.77481460571289     │
# │         test/ssim         │    0.9271323680877686     │
# └───────────────────────────┴───────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# VBox(children=(Label(value='0.010 MB of 0.032 MB uploaded\r'), FloatProgress(value=0.3312051801869951, max=1.0…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▂▂▃▃▃▃▃▃▃▃▄▄▄▅▅▅▅▅▅▅▅▆▆▇▇▇▇▇▇▇▇███</td></tr><tr><td>test/loss</td><td>▁</td></tr><tr><td>test/psnr</td><td>▁</td></tr><tr><td>test/ssim</td><td>▁</td></tr><tr><td>train/loss</td><td>█▃▂▂▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇█████</td></tr><tr><td>val/loss</td><td>█▆▅▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>val/psnr</td><td>▁▂▃▄▄▅▅▅▅▅▅▆▆▅▆▆▆▆▇▇▇▇▇▇▇▇████</td></tr><tr><td>val/psnr_best</td><td>▁▂▃▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇████</td></tr><tr><td>val/ssim</td><td>▁▃▄▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇████</td></tr><tr><td>val/ssim_best</td><td>▁▃▄▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>15</td></tr><tr><td>test/loss</td><td>0.02312</td></tr><tr><td>test/psnr</td><td>33.77481</td></tr><tr><td>test/ssim</td><td>0.92713</td></tr><tr><td>train/loss</td><td>0.02368</td></tr><tr><td>trainer/global_step</td><td>12180</td></tr><tr><td>val/loss</td><td>0.02314</td></tr><tr><td>val/psnr</td><td>33.89455</td></tr><tr><td>val/psnr_best</td><td>33.89455</td></tr><tr><td>val/ssim</td><td>0.92721</td></tr><tr><td>val/ssim_best</td><td>0.92721</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">maevit_pretrain_l22_uscont</strong> at: <a href='https://wandb.ai/adaruna3/cmta3-pretrain-maevit/runs/zbvvtvxa/workspace' target="_blank">https://wandb.ai/adaruna3/cmta3-pretrain-maevit/runs/zbvvtvxa/workspace</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>../../logs/cmta3-pretrain-maevit/runs/2024-03-26_21-04-46/wandb/run-20240326_210448-zbvvtvxa/logs</code>

# %% [markdown]
# If pretraining completed successfully, you will see the outputs of all the logging running when pretraining above. By carefully reading through the logs above, you will find where the model checkpoints, logs, and other generated files are stored. These can also be accessed using return values of pretrain above.
#
# Now that we've pretrained the MAE, we can use the pretrained MAE as a backbone to finetune a deposit prospectivity model.
#
# The config used below is for MaNiAC; however, changing the config for another deposit that exists in our repo is as easy as changing a single paramter (and using the correct pretrain backbone that corresponds to that deposit type). Simply modify the "experiment" variable above with the overrides to a different MAE classifier [experiment](../configs/experiment/). Current MAE classifier experiment configs available are:
# * exp_maniac_maevit_classifier_l22_uscont
# * exp_mvt_maevit_classifier_l22_uscont
# * exp_w_maevit_classifier_l22_uscont
#
# Note - the `exp_mvt_maevit_classifier_l22_uscont` and `exp_w_maevit_classifier_l22_uscont` experiment configs use a backbone generated by `exp_maevit_pretrain_l22_uscont`, while `exp_maniac_maevit_classifier_l22_uscont` uses `exp_maniac_maevit_pretrain_l22_uscont`. This is because the national-scale MaNiAC experiments (currently) use a differnt set of evidence layers than the MVT Lead-Zinc or Tungsten-skarn experiments. Soon we plan to train MAEs for each modality / mineral system so modality specific MAEs can be swapped in/out without the need to pretrain if the evidence layers change.
#
# Now we generate a config file to train a classifier for MaNiAC using the pretrained MAE for MaNiAC.

# %%
train_cfg = build_hydra_config_notebook(overrides=["experiment=exp_maniac_maevit_classifier_l22_uscont","trainer=gpu"])
train_cfg.model.net.backbone_ckpt = pretrain_objs["trainer"].checkpoint_callback.best_model_path # sets model backbone
print_config_tree(train_cfg)
# Out:
# CONFIG
# ├── data
# │   └── _target_: sri_maper.src.data.tiff_datamodule.TIFFDataModule
# │       tif_dir: ${paths.data_dir}/H3/MaNiAC
# │       window_size: 33
# │       multiplier: 20
# │       downsample: true
# │       oversample: true
# │       likely_neg_range:
# │       - 0.75
# │       - 1.0
# │       batch_size: 32
# │       num_workers: 12
# │       pin_memory: false
# │       seed: ${seed}
# │       log_path: ${paths.output_dir}
# │
# ├── model
# │   └── _target_: sri_maper.src.models.cma_module.CMALitModule
# │       optimizer:
# │         _target_: torch.optim.AdamW
# │         _partial_: true
# │         lr: 0.0001
# │         weight_decay: 0.001
# │       scheduler:
# │         _target_: torch.optim.lr_scheduler.ReduceLROnPlateau
# │         _partial_: true
# │         mode: min
# │         factor: 0.1
# │         patience: 10
# │       net:
# │         _target_: sri_maper.src.models.mae_vit_classifier.CLSClassifer
# │         backbone_ckpt: ../../logs/cmta3-pretrain-maevit/runs/2024-03-26_21-04-46/checkpoints/ssim_0.927.ckpt
# │         backbone_net:
# │           _target_: sri_maper.src.models.mae_vit.MAE_ViT
# │           image_size: 33
# │           patch_size: 3
# │           input_dim: 14
# │           enc_dim: 256
# │           encoder_layer: 6
# │           encoder_head: 8
# │           dec_dim: 128
# │           output_dim: 14
# │           decoder_layer: 2
# │           decoder_head: 4
# │           mask_ratio: 0.75
# │         freeze_backbone: false
# │         dropout_rate: 0.5
# │       compile: false
# │       mc_samples: 100
# │       gain: 1.0
# │       smoothing: 0.2
# │       extract_attributions: ${extract_attributions}
# │
# ├── callbacks
# │   └── model_checkpoint:
# │         _target_: pytorch_lightning.callbacks.ModelCheckpoint
# │         dirpath: ${paths.output_dir}/checkpoints
# │         filename: auprc_{val/auprc:.3f}
# │         monitor: val/auprc
# │         verbose: false
# │         save_last: true
# │         save_top_k: 1
# │         mode: max
# │         auto_insert_metric_name: false
# │         save_weights_only: false
# │         every_n_train_steps: null
# │         train_time_interval: null
# │         every_n_epochs: null
# │         save_on_train_epoch_end: null
# │       early_stopping:
# │         _target_: pytorch_lightning.callbacks.EarlyStopping
# │         monitor: val/auprc_best
# │         min_delta: 0.0
# │         patience: 6
# │         verbose: false
# │         mode: max
# │         strict: true
# │         check_finite: true
# │         stopping_threshold: null
# │         divergence_threshold: null
# │         check_on_train_epoch_end: null
# │       model_summary:
# │         _target_: pytorch_lightning.callbacks.RichModelSummary
# │         max_depth: -1
# │       rich_progress_bar:
# │         _target_: pytorch_lightning.callbacks.RichProgressBar
# │
# ├── logger
# │   └── wandb:
# │         _target_: pytorch_lightning.loggers.wandb.WandbLogger
# │         save_dir: ${paths.output_dir}
# │         offline: false
# │         id: null
# │         anonymous: null
# │         project: ${task_name}
# │         log_model: false
# │         prefix: ''
# │         group: ''
# │         tags: ${tags}
# │         job_type: ''
# │         name: exp_ni_maevit_classifier_l22_uscont
# │
# ├── trainer
# │   └── _target_: pytorch_lightning.Trainer
# │       default_root_dir: ${paths.output_dir}
# │       min_epochs: 1
# │       max_epochs: 100
# │       accelerator: gpu
# │       devices: 1
# │       precision: 16
# │       val_check_interval: 0.5
# │       deterministic: false
# │       benchmark: true
# │       limit_train_batches: 1.0
# │       limit_val_batches: 1.0
# │       limit_test_batches: 1.0
# │
# ├── paths
# │   └── root_dir: ../..
# │       work_dir: ${hydra:runtime.cwd}
# │       data_dir: ${paths.root_dir}/data
# │       log_dir: ${paths.root_dir}/logs
# │       output_dir: ${hydra.run.dir}
# │
# ├── extras
# │   └── ignore_warnings: false
# │       enforce_tags: false
# │       print_config: false
# │
# ├── hydra
# │   └── run:
# │         dir: ${paths.log_dir}/${task_name}/runs/${now:%Y-%m-%d}_${now:%H-%M-%S}
# │       sweep:
# │         dir: ${paths.log_dir}/${task_name}/multiruns/${now:%Y-%m-%d}_${now:%H-%M-%S}
# │         subdir: ${hydra.job.num}
# │       launcher:
# │         _target_: hydra._internal.core_plugins.basic_launcher.BasicLauncher
# │       sweeper:
# │         _target_: hydra._internal.core_plugins.basic_sweeper.BasicSweeper
# │         max_batch_size: null
# │         params: null
# │       help:
# │         app_name: ${hydra.job.name}
# │         header: '${hydra.help.app_name} is powered by Hydra.
# │
# │           '
# │         footer: 'Powered by Hydra (https://hydra.cc)
# │
# │           Use --hydra-help to view Hydra specific help
# │
# │           '
# │         template: '${hydra.help.header}
# │
# │           == Configuration groups ==
# │
# │           Compose your configuration from those groups (group=option)
# │
# │
# │           $APP_CONFIG_GROUPS
# │
# │
# │           == Config ==
# │
# │           Override anything in the config (foo.bar=value)
# │
# │
# │           $CONFIG
# │
# │
# │           ${hydra.help.footer}
# │
# │           '
# │       hydra_help:
# │         template: 'Hydra (${hydra.runtime.version})
# │
# │           See https://hydra.cc for more info.
# │
# │
# │           == Flags ==
# │
# │           $FLAGS_HELP
# │
# │
# │           == Configuration groups ==
# │
# │           Compose your configuration from those groups (For example, append hydra/job_logging=disabled
# │           to command line)
# │
# │
# │           $HYDRA_CONFIG_GROUPS
# │
# │
# │           Use ''--cfg hydra'' to Show the Hydra config.
# │
# │           '
# │         hydra_help: ???
# │       hydra_logging:
# │         version: 1
# │         formatters:
# │           colorlog:
# │             (): colorlog.ColoredFormatter
# │             format: '[%(cyan)s%(asctime)s%(reset)s][%(purple)sHYDRA%(reset)s] %(message)s'
# │         handlers:
# │           console:
# │             class: logging.StreamHandler
# │             formatter: colorlog
# │             stream: ext://sys.stdout
# │         root:
# │           level: INFO
# │           handlers:
# │           - console
# │         disable_existing_loggers: false
# │       job_logging:
# │         version: 1
# │         formatters:
# │           simple:
# │             format: '[%(asctime)s][%(name)s][%(levelname)s] - %(message)s'
# │           colorlog:
# │             (): colorlog.ColoredFormatter
# │             format: '[%(cyan)s%(asctime)s%(reset)s][%(blue)s%(name)s%(reset)s][%(log_color)s%(levelname)s%(reset)
# │               - %(message)s'
# │             log_colors:
# │               DEBUG: purple
# │               INFO: green
# │               WARNING: yellow
# │               ERROR: red
# │               CRITICAL: red
# │         handlers:
# │           console:
# │             class: logging.StreamHandler
# │             formatter: colorlog
# │             stream: ext://sys.stdout
# │           file:
# │             class: logging.FileHandler
# │             formatter: simple
# │             filename: ${paths.output_dir}/${task_name}.log
# │         root:
# │           level: INFO
# │           handlers:
# │           - console
# │           - file
# │         disable_existing_loggers: false
# │       env: {}
# │       mode: null
# │       searchpath: []
# │       callbacks: {}
# │       output_subdir: .hydra
# │       overrides:
# │         hydra: []
# │         task:
# │         - paths.root_dir=../..
# │         - paths.output_dir=${hydra.run.dir}
# │         - extras.print_config=false
# │         - extras.enforce_tags=false
# │         - experiment=exp_maniac_maevit_classifier_l22_uscont
# │         - trainer=gpu
# │       job:
# │         name: app
# │         chdir: null
# │         override_dirname: experiment=exp_maniac_maevit_classifier_l22_uscont,extras.enforce_tags=false,extras.pri
# │         id: ???
# │         num: ???
# │         config_name: train.yaml
# │         env_set: {}
# │         env_copy: []
# │         config:
# │           override_dirname:
# │             kv_sep: '='
# │             item_sep: ','
# │             exclude_keys: []
# │       runtime:
# │         version: 1.3.2
# │         version_base: '1.3'
# │         cwd: /workspace/sri_maper/notebooks
# │         config_sources:
# │         - path: hydra.conf
# │           schema: pkg
# │           provider: hydra
# │         - path: sri_maper.configs
# │           schema: pkg
# │           provider: main
# │         - path: hydra_plugins.hydra_colorlog.conf
# │           schema: pkg
# │           provider: hydra-colorlog
# │         - path: ''
# │           schema: structured
# │           provider: schema
# │         output_dir: ???
# │         choices:
# │           debug: null
# │           local: default.yaml
# │           hparams_search: null
# │           experiment: exp_maniac_maevit_classifier_l22_uscont
# │           hydra: default.yaml
# │           extras: default.yaml
# │           paths: default.yaml
# │           trainer: gpu
# │           logger: wandb.yaml
# │           callbacks: default.yaml
# │           model: maevit_classifier.yaml
# │           data: default.yaml
# │           preprocess: maniac-natl.yaml
# │           hydra/env: default
# │           hydra/callbacks: null
# │           hydra/job_logging: colorlog
# │           hydra/hydra_logging: colorlog
# │           hydra/hydra_help: default
# │           hydra/help: default
# │           hydra/sweeper: basic
# │           hydra/launcher: basic
# │           hydra/output: default
# │       verbose: false
# │
# ├── task_name
# │   └── cmta3-classifier-maevit
# ├── tags
# │   └── ['ni_maniac', 'mae-vit-classifier-cls']
# ├── train
# │   └── True
# ├── test
# │   └── True
# ├── tune
# │   └── False
# ├── ckpt_path
# │   └── None
# ├── seed
# │   └── 1234
# ├── preprocess
# │   └── _target_: sri_maper.src.data.preprocessing.generate_raster_stacks
# │       raster_stacks:
# │       - raster_stack_path: ${data.tif_dir}/maniac-natl.tif
# │         raster_files_path: ${paths.data_dir}/raster_library
# │         raster_files:
# │         - Geophysics/Seismic/Geophysics_LAB_clipped_dilated.tif
# │         - Geophysics/Seismic/Geophysics_LAB_HGM_clipped_dilated.tif
# │         - Geophysics/Seismic/Geophysics_LAB_HGM_Worms_clipped_dilated.tif
# │         - Geophysics/Seismic/Geophysics_Moho_clipped_dilated.tif
# │         - Geophysics/Magnetics/Geophysics_Mag_LOGAnalyticSignal_clipped_dilated.tif
# │         - Geophysics/Magnetics/Geophysics_Mag_RTP_Long-Wavelength_HGM_Worms_clipped_dilated.tif
# │         - Geophysics/Magnetics/Geophysics_Mag_RTP_clipped_dilated.tif
# │         - Geophysics/Magnetics/Geophysics_Mag_RTP_Long-Wavelength_HGM_clipped_dilated.tif
# │         - Geophysics/MT/Geophysics_MT2023_9km_clipped_dilated.tif
# │         - Geophysics/MT/Geophysics_MT2023_15km_clipped_dilated.tif
# │         - Geophysics/MT/Geophysics_MT2023_30km_clipped_dilated.tif
# │         - Geophysics/Gravity/Geophysics_Gravity_Isostatic_clipped_dilated.tif
# │         - Geophysics/Gravity/Geophysics_Gravity_Bouguer_Up30km_HGM_clipped_dilated.tif
# │         - Geophysics/Gravity/Geophysics_Gravity_Bouguer_Up30km_HGM_Worms_clipped_dilated.tif
# │         - Labels/magmatic_nickel_sites_v1h2merged_cont_US_clipped_dilated.tif
# │         raster_files_types:
# │         - float32
# │         - float32
# │         - float32
# │         - float32
# │         - float32
# │         - float32
# │         - float32
# │         - float32
# │         - float32
# │         - float32
# │         - float32
# │         - float32
# │         - float32
# │         - float32
# │         - bool
# │
# └── extract_attributions
#     └── True

# %% [markdown]
# Now we can use the generated config file to run the experiment. We pass this config file to the [train task](../src/train.py), which returns metrics and objects created during the run.

# %%
train_metrics, train_objs = train(train_cfg)
# Out:
# Global seed set to 1234
# 100%|██████████| 1/1 [00:00<00:00, 497.31it/s]
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113514233794477, max=1.0…
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>../../logs/cmta3-classifier-maevit/runs/2024-03-26_21-49-14/wandb/run-20240326_214914-67rlvh2e</code>
# Syncing run <strong><a href='https://wandb.ai/adaruna3/cmta3-classifier-maevit/runs/67rlvh2e/workspace' target="_blank">exp_ni_maevit_classifier_l22_uscont</a></strong> to <a href='https://wandb.ai/adaruna3/cmta3-classifier-maevit' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adaruna3/cmta3-classifier-maevit' target="_blank">https://wandb.ai/adaruna3/cmta3-classifier-maevit</a>
#  View run at <a href='https://wandb.ai/adaruna3/cmta3-classifier-maevit/runs/67rlvh2e/workspace' target="_blank">https://wandb.ai/adaruna3/cmta3-classifier-maevit/runs/67rlvh2e/workspace</a>
# Using 16bit None Automatic Mixed Precision (AMP)
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_test_batches=1.0)` was configured so 100% of the batches will be used..
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# ┏━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓
# ┃     ┃ Name                                   ┃ Type                   ┃ Params ┃
# ┡━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩
# │ 0   │ net                                    │ CLSClassifer           │  4.8 M │
# │ 1   │ net.backbone                           │ MAE_Encoder            │  4.8 M │
# │ 2   │ net.backbone.patch_embedding           │ Sequential             │ 32.5 K │
# │ 3   │ net.backbone.patch_embedding.0         │ Conv2d                 │ 32.5 K │
# │ 4   │ net.backbone.patch_embedding.1         │ Flatten                │      0 │
# │ 5   │ net.backbone.patch_drop                │ DummyPatchDropLayer    │      0 │
# │ 6   │ net.backbone.backbone                  │ Sequential             │  4.7 M │
# │ 7   │ net.backbone.backbone.0                │ Block                  │  788 K │
# │ 8   │ net.backbone.backbone.0.norm1          │ LayerNorm              │    512 │
# │ 9   │ net.backbone.backbone.0.attn           │ Attention              │  262 K │
# │ 10  │ net.backbone.backbone.0.attn.qkv       │ Linear                 │  196 K │
# │ 11  │ net.backbone.backbone.0.attn.q_norm    │ Identity               │      0 │
# │ 12  │ net.backbone.backbone.0.attn.k_norm    │ Identity               │      0 │
# │ 13  │ net.backbone.backbone.0.attn.attn_drop │ Dropout                │      0 │
# │ 14  │ net.backbone.backbone.0.attn.proj      │ Linear                 │ 65.8 K │
# │ 15  │ net.backbone.backbone.0.attn.proj_drop │ Dropout                │      0 │
# │ 16  │ net.backbone.backbone.0.ls1            │ Identity               │      0 │
# │ 17  │ net.backbone.backbone.0.drop_path1     │ Identity               │      0 │
# │ 18  │ net.backbone.backbone.0.norm2          │ LayerNorm              │    512 │
# │ 19  │ net.backbone.backbone.0.mlp            │ Mlp                    │  525 K │
# │ 20  │ net.backbone.backbone.0.mlp.fc1        │ Linear                 │  263 K │
# │ 21  │ net.backbone.backbone.0.mlp.act        │ GELU                   │      0 │
# │ 22  │ net.backbone.backbone.0.mlp.drop1      │ Dropout                │      0 │
# │ 23  │ net.backbone.backbone.0.mlp.norm       │ Identity               │      0 │
# │ 24  │ net.backbone.backbone.0.mlp.fc2        │ Linear                 │  262 K │
# │ 25  │ net.backbone.backbone.0.mlp.drop2      │ Dropout                │      0 │
# │ 26  │ net.backbone.backbone.0.ls2            │ Identity               │      0 │
# │ 27  │ net.backbone.backbone.0.drop_path2     │ Identity               │      0 │
# │ 28  │ net.backbone.backbone.1                │ Block                  │  788 K │
# │ 29  │ net.backbone.backbone.1.norm1          │ LayerNorm              │    512 │
# │ 30  │ net.backbone.backbone.1.attn           │ Attention              │  262 K │
# │ 31  │ net.backbone.backbone.1.attn.qkv       │ Linear                 │  196 K │
# │ 32  │ net.backbone.backbone.1.attn.q_norm    │ Identity               │      0 │
# │ 33  │ net.backbone.backbone.1.attn.k_norm    │ Identity               │      0 │
# │ 34  │ net.backbone.backbone.1.attn.attn_drop │ Dropout                │      0 │
# │ 35  │ net.backbone.backbone.1.attn.proj      │ Linear                 │ 65.8 K │
# │ 36  │ net.backbone.backbone.1.attn.proj_drop │ Dropout                │      0 │
# │ 37  │ net.backbone.backbone.1.ls1            │ Identity               │      0 │
# │ 38  │ net.backbone.backbone.1.drop_path1     │ Identity               │      0 │
# │ 39  │ net.backbone.backbone.1.norm2          │ LayerNorm              │    512 │
# │ 40  │ net.backbone.backbone.1.mlp            │ Mlp                    │  525 K │
# │ 41  │ net.backbone.backbone.1.mlp.fc1        │ Linear                 │  263 K │
# │ 42  │ net.backbone.backbone.1.mlp.act        │ GELU                   │      0 │
# │ 43  │ net.backbone.backbone.1.mlp.drop1      │ Dropout                │      0 │
# │ 44  │ net.backbone.backbone.1.mlp.norm       │ Identity               │      0 │
# │ 45  │ net.backbone.backbone.1.mlp.fc2        │ Linear                 │  262 K │
# │ 46  │ net.backbone.backbone.1.mlp.drop2      │ Dropout                │      0 │
# │ 47  │ net.backbone.backbone.1.ls2            │ Identity               │      0 │
# │ 48  │ net.backbone.backbone.1.drop_path2     │ Identity               │      0 │
# │ 49  │ net.backbone.backbone.2                │ Block                  │  788 K │
# │ 50  │ net.backbone.backbone.2.norm1          │ LayerNorm              │    512 │
# │ 51  │ net.backbone.backbone.2.attn           │ Attention              │  262 K │
# │ 52  │ net.backbone.backbone.2.attn.qkv       │ Linear                 │  196 K │
# │ 53  │ net.backbone.backbone.2.attn.q_norm    │ Identity               │      0 │
# │ 54  │ net.backbone.backbone.2.attn.k_norm    │ Identity               │      0 │
# │ 55  │ net.backbone.backbone.2.attn.attn_drop │ Dropout                │      0 │
# │ 56  │ net.backbone.backbone.2.attn.proj      │ Linear                 │ 65.8 K │
# │ 57  │ net.backbone.backbone.2.attn.proj_drop │ Dropout                │      0 │
# │ 58  │ net.backbone.backbone.2.ls1            │ Identity               │      0 │
# │ 59  │ net.backbone.backbone.2.drop_path1     │ Identity               │      0 │
# │ 60  │ net.backbone.backbone.2.norm2          │ LayerNorm              │    512 │
# │ 61  │ net.backbone.backbone.2.mlp            │ Mlp                    │  525 K │
# │ 62  │ net.backbone.backbone.2.mlp.fc1        │ Linear                 │  263 K │
# │ 63  │ net.backbone.backbone.2.mlp.act        │ GELU                   │      0 │
# │ 64  │ net.backbone.backbone.2.mlp.drop1      │ Dropout                │      0 │
# │ 65  │ net.backbone.backbone.2.mlp.norm       │ Identity               │      0 │
# │ 66  │ net.backbone.backbone.2.mlp.fc2        │ Linear                 │  262 K │
# │ 67  │ net.backbone.backbone.2.mlp.drop2      │ Dropout                │      0 │
# │ 68  │ net.backbone.backbone.2.ls2            │ Identity               │      0 │
# │ 69  │ net.backbone.backbone.2.drop_path2     │ Identity               │      0 │
# │ 70  │ net.backbone.backbone.3                │ Block                  │  788 K │
# │ 71  │ net.backbone.backbone.3.norm1          │ LayerNorm              │    512 │
# │ 72  │ net.backbone.backbone.3.attn           │ Attention              │  262 K │
# │ 73  │ net.backbone.backbone.3.attn.qkv       │ Linear                 │  196 K │
# │ 74  │ net.backbone.backbone.3.attn.q_norm    │ Identity               │      0 │
# │ 75  │ net.backbone.backbone.3.attn.k_norm    │ Identity               │      0 │
# │ 76  │ net.backbone.backbone.3.attn.attn_drop │ Dropout                │      0 │
# │ 77  │ net.backbone.backbone.3.attn.proj      │ Linear                 │ 65.8 K │
# │ 78  │ net.backbone.backbone.3.attn.proj_drop │ Dropout                │      0 │
# │ 79  │ net.backbone.backbone.3.ls1            │ Identity               │      0 │
# │ 80  │ net.backbone.backbone.3.drop_path1     │ Identity               │      0 │
# │ 81  │ net.backbone.backbone.3.norm2          │ LayerNorm              │    512 │
# │ 82  │ net.backbone.backbone.3.mlp            │ Mlp                    │  525 K │
# │ 83  │ net.backbone.backbone.3.mlp.fc1        │ Linear                 │  263 K │
# │ 84  │ net.backbone.backbone.3.mlp.act        │ GELU                   │      0 │
# │ 85  │ net.backbone.backbone.3.mlp.drop1      │ Dropout                │      0 │
# │ 86  │ net.backbone.backbone.3.mlp.norm       │ Identity               │      0 │
# │ 87  │ net.backbone.backbone.3.mlp.fc2        │ Linear                 │  262 K │
# │ 88  │ net.backbone.backbone.3.mlp.drop2      │ Dropout                │      0 │
# │ 89  │ net.backbone.backbone.3.ls2            │ Identity               │      0 │
# │ 90  │ net.backbone.backbone.3.drop_path2     │ Identity               │      0 │
# │ 91  │ net.backbone.backbone.4                │ Block                  │  788 K │
# │ 92  │ net.backbone.backbone.4.norm1          │ LayerNorm              │    512 │
# │ 93  │ net.backbone.backbone.4.attn           │ Attention              │  262 K │
# │ 94  │ net.backbone.backbone.4.attn.qkv       │ Linear                 │  196 K │
# │ 95  │ net.backbone.backbone.4.attn.q_norm    │ Identity               │      0 │
# │ 96  │ net.backbone.backbone.4.attn.k_norm    │ Identity               │      0 │
# │ 97  │ net.backbone.backbone.4.attn.attn_drop │ Dropout                │      0 │
# │ 98  │ net.backbone.backbone.4.attn.proj      │ Linear                 │ 65.8 K │
# │ 99  │ net.backbone.backbone.4.attn.proj_drop │ Dropout                │      0 │
# │ 100 │ net.backbone.backbone.4.ls1            │ Identity               │      0 │
# │ 101 │ net.backbone.backbone.4.drop_path1     │ Identity               │      0 │
# │ 102 │ net.backbone.backbone.4.norm2          │ LayerNorm              │    512 │
# │ 103 │ net.backbone.backbone.4.mlp            │ Mlp                    │  525 K │
# │ 104 │ net.backbone.backbone.4.mlp.fc1        │ Linear                 │  263 K │
# │ 105 │ net.backbone.backbone.4.mlp.act        │ GELU                   │      0 │
# │ 106 │ net.backbone.backbone.4.mlp.drop1      │ Dropout                │      0 │
# │ 107 │ net.backbone.backbone.4.mlp.norm       │ Identity               │      0 │
# │ 108 │ net.backbone.backbone.4.mlp.fc2        │ Linear                 │  262 K │
# │ 109 │ net.backbone.backbone.4.mlp.drop2      │ Dropout                │      0 │
# │ 110 │ net.backbone.backbone.4.ls2            │ Identity               │      0 │
# │ 111 │ net.backbone.backbone.4.drop_path2     │ Identity               │      0 │
# │ 112 │ net.backbone.backbone.5                │ Block                  │  788 K │
# │ 113 │ net.backbone.backbone.5.norm1          │ LayerNorm              │    512 │
# │ 114 │ net.backbone.backbone.5.attn           │ Attention              │  262 K │
# │ 115 │ net.backbone.backbone.5.attn.qkv       │ Linear                 │  196 K │
# │ 116 │ net.backbone.backbone.5.attn.q_norm    │ Identity               │      0 │
# │ 117 │ net.backbone.backbone.5.attn.k_norm    │ Identity               │      0 │
# │ 118 │ net.backbone.backbone.5.attn.attn_drop │ Dropout                │      0 │
# │ 119 │ net.backbone.backbone.5.attn.proj      │ Linear                 │ 65.8 K │
# │ 120 │ net.backbone.backbone.5.attn.proj_drop │ Dropout                │      0 │
# │ 121 │ net.backbone.backbone.5.ls1            │ Identity               │      0 │
# │ 122 │ net.backbone.backbone.5.drop_path1     │ Identity               │      0 │
# │ 123 │ net.backbone.backbone.5.norm2          │ LayerNorm              │    512 │
# │ 124 │ net.backbone.backbone.5.mlp            │ Mlp                    │  525 K │
# │ 125 │ net.backbone.backbone.5.mlp.fc1        │ Linear                 │  263 K │
# │ 126 │ net.backbone.backbone.5.mlp.act        │ GELU                   │      0 │
# │ 127 │ net.backbone.backbone.5.mlp.drop1      │ Dropout                │      0 │
# │ 128 │ net.backbone.backbone.5.mlp.norm       │ Identity               │      0 │
# │ 129 │ net.backbone.backbone.5.mlp.fc2        │ Linear                 │  262 K │
# │ 130 │ net.backbone.backbone.5.mlp.drop2      │ Dropout                │      0 │
# │ 131 │ net.backbone.backbone.5.ls2            │ Identity               │      0 │
# │ 132 │ net.backbone.backbone.5.drop_path2     │ Identity               │      0 │
# │ 133 │ net.backbone.layer_norm                │ LayerNorm              │    512 │
# │ 134 │ net.ff                                 │ Sequential             │    256 │
# │ 135 │ net.ff.0                               │ Dropout                │      0 │
# │ 136 │ net.ff.1                               │ Linear                 │    256 │
# │ 137 │ criterion                              │ BCEWithLogitsLoss      │      0 │
# │ 138 │ val_auc                                │ BinaryAUROC            │      0 │
# │ 139 │ test_auc                               │ BinaryAUROC            │      0 │
# │ 140 │ val_auprc                              │ BinaryAveragePrecision │      0 │
# │ 141 │ test_auprc                             │ BinaryAveragePrecision │      0 │
# │ 142 │ test_bal_acc                           │ MulticlassAccuracy     │      0 │
# │ 143 │ test_acc                               │ BinaryAccuracy         │      0 │
# │ 144 │ test_mcc                               │ BinaryMatthewsCorrCoef │      0 │
# │ 145 │ test_f1                                │ BinaryF1Score          │      0 │
# │ 146 │ train_loss                             │ MeanMetric             │      0 │
# │ 147 │ val_loss                               │ MeanMetric             │      0 │
# │ 148 │ test_loss                              │ MeanMetric             │      0 │
# │ 149 │ val_auc_best                           │ MaxMetric              │      0 │
# │ 150 │ val_auprc_best                         │ MaxMetric              │      0 │
# └─────┴────────────────────────────────────────┴────────────────────────┴────────┘
# Trainable params: 4.8 M
# Non-trainable params: 0
# Total params: 4.8 M
# Total estimated model params size (MB): 9
# Output()
# /opt/conda/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: No positive samples in
# targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)  # noqa: B028
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# /opt/conda/lib/python3.10/site-packages/pytorch_lightning/utilities/parsing.py:269: UserWarning: Attribute 'net' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['net'])`.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Output()
# /opt/conda/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: No positive samples in
# targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)  # noqa: B028
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test/acc          │    0.9798761606216431     │
# │         test/auc          │    0.9680304527282715     │
# │        test/auprc         │    0.9102819561958313     │
# │       test/bal_acc        │    0.8209546208381653     │
# │          test/f1          │    0.7547169923782349     │
# │         test/loss         │    0.3928317129611969     │
# │         test/mcc          │    0.7564642429351807     │
# └───────────────────────────┴───────────────────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# VBox(children=(Label(value='0.010 MB of 0.033 MB uploaded\r'), FloatProgress(value=0.3190776048043846, max=1.0…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▃▃▃▅▅▅▆▆█</td></tr><tr><td>test/acc</td><td>▁</td></tr><tr><td>test/auc</td><td>▁</td></tr><tr><td>test/auprc</td><td>▁</td></tr><tr><td>test/bal_acc</td><td>▁</td></tr><tr><td>test/f1</td><td>▁</td></tr><tr><td>test/loss</td><td>▁</td></tr><tr><td>test/mcc</td><td>▁</td></tr><tr><td>train/loss</td><td>█▂▁▁</td></tr><tr><td>trainer/global_step</td><td>▁▂▂▃▄▅▆▇▇███</td></tr><tr><td>val/auc</td><td>█▄▇▁▃▅▆</td></tr><tr><td>val/auc_best</td><td>▁▁▁▁▁▁▁</td></tr><tr><td>val/auprc</td><td>█▄▂▂▂▇▁</td></tr><tr><td>val/auprc_best</td><td>▁▁▁▁▁▁▁</td></tr><tr><td>val/loss</td><td>█▃▄▂▃▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>test/acc</td><td>0.97988</td></tr><tr><td>test/auc</td><td>0.96803</td></tr><tr><td>test/auprc</td><td>0.91028</td></tr><tr><td>test/bal_acc</td><td>0.82095</td></tr><tr><td>test/f1</td><td>0.75472</td></tr><tr><td>test/loss</td><td>0.39283</td></tr><tr><td>test/mcc</td><td>0.75646</td></tr><tr><td>train/loss</td><td>0.33689</td></tr><tr><td>trainer/global_step</td><td>269</td></tr><tr><td>val/auc</td><td>0.98017</td></tr><tr><td>val/auc_best</td><td>0.9834</td></tr><tr><td>val/auprc</td><td>0.81173</td></tr><tr><td>val/auprc_best</td><td>0.89637</td></tr><tr><td>val/loss</td><td>0.34723</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">exp_ni_maevit_classifier_l22_uscont</strong> at: <a href='https://wandb.ai/adaruna3/cmta3-classifier-maevit/runs/67rlvh2e/workspace' target="_blank">https://wandb.ai/adaruna3/cmta3-classifier-maevit/runs/67rlvh2e/workspace</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>../../logs/cmta3-classifier-maevit/runs/2024-03-26_21-49-14/wandb/run-20240326_214914-67rlvh2e/logs</code>

# %% [markdown]
# If training completed successfully, you will see the outputs of all the logging running when training above. By carefully reading through the logs above, you will find where the model checkpoints, logs, and other generated files are stored. These can also be accessed using return values of train above.
#
# For example, let's test the trained model again using the [test task](../src/test.py). Note - testing is optionally included in the training above and can be disabled by modifying the experiment config.

# %%
train_cfg.ckpt_path = train_objs["trainer"].checkpoint_callback.best_model_path # required for test
test_metrics, test_objs = test(train_cfg)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 750.59it/s]
# /opt/conda/lib/python3.10/site-packages/pytorch_lightning/utilities/parsing.py:269: UserWarning: Attribute 'net' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['net'])`.
#   rank_zero_warn(
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>../../logs/cmta3-classifier-maevit/runs/2024-03-26_21-49-14/wandb/run-20240326_215905-av4x77uz</code>
# Syncing run <strong><a href='https://wandb.ai/adaruna3/cmta3-classifier-maevit/runs/av4x77uz/workspace' target="_blank">exp_ni_maevit_classifier_l22_uscont</a></strong> to <a href='https://wandb.ai/adaruna3/cmta3-classifier-maevit' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adaruna3/cmta3-classifier-maevit' target="_blank">https://wandb.ai/adaruna3/cmta3-classifier-maevit</a>
#  View run at <a href='https://wandb.ai/adaruna3/cmta3-classifier-maevit/runs/av4x77uz/workspace' target="_blank">https://wandb.ai/adaruna3/cmta3-classifier-maevit/runs/av4x77uz/workspace</a>
# Using 16bit None Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_test_batches=1.0)` was configured so 100% of the batches will be used..
# /opt/conda/lib/python3.10/site-packages/pytorch_lightning/utilities/parsing.py:269: UserWarning: Attribute 'net' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['net'])`.
#   rank_zero_warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Testing: 0it [00:00, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)  # noqa: B028
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test/acc          │    0.9798761606216431     │
# │         test/auc          │    0.9680304527282715     │
# │        test/auprc         │    0.9102819561958313     │
# │       test/bal_acc        │    0.8209546208381653     │
# │          test/f1          │    0.7547169923782349     │
# │         test/loss         │    0.3928317129611969     │
# │         test/mcc          │    0.7564642429351807     │
# └───────────────────────────┴───────────────────────────┘
# VBox(children=(Label(value='0.010 MB of 0.010 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁</td></tr><tr><td>test/acc</td><td>▁</td></tr><tr><td>test/auc</td><td>▁</td></tr><tr><td>test/auprc</td><td>▁</td></tr><tr><td>test/bal_acc</td><td>▁</td></tr><tr><td>test/f1</td><td>▁</td></tr><tr><td>test/loss</td><td>▁</td></tr><tr><td>test/mcc</td><td>▁</td></tr><tr><td>trainer/global_step</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>0</td></tr><tr><td>test/acc</td><td>0.97988</td></tr><tr><td>test/auc</td><td>0.96803</td></tr><tr><td>test/auprc</td><td>0.91028</td></tr><tr><td>test/bal_acc</td><td>0.82095</td></tr><tr><td>test/f1</td><td>0.75472</td></tr><tr><td>test/loss</td><td>0.39283</td></tr><tr><td>test/mcc</td><td>0.75646</td></tr><tr><td>trainer/global_step</td><td>0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">exp_ni_maevit_classifier_l22_uscont</strong> at: <a href='https://wandb.ai/adaruna3/cmta3-classifier-maevit/runs/av4x77uz/workspace' target="_blank">https://wandb.ai/adaruna3/cmta3-classifier-maevit/runs/av4x77uz/workspace</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>../../logs/cmta3-classifier-maevit/runs/2024-03-26_21-49-14/wandb/run-20240326_215905-av4x77uz/logs</code>

# %% [markdown]
# You'll notice the repeated testing shows our experiments / testing are repeatable as all metrics match up to 4 significant figures.
#
# Note, `train`, `test`, and `build_map` (below) all can run individually and with different configs. Below we'll build a map and use a different config to do so, by manipulating the existing one. Below we've elected to use a larger batch size during mapping.

# %%
train_cfg.data.batch_size=128
maniac_maps, _ = build_map(train_cfg)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 1038.45it/s]
# /opt/conda/lib/python3.10/site-packages/pytorch_lightning/utilities/parsing.py:269: UserWarning: Attribute 'net' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['net'])`.
#   rank_zero_warn(
# Tracking run with wandb version 0.16.5
# Run data is saved locally in <code>../../logs/cmta3-classifier-maevit/runs/2024-03-26_21-49-14/wandb/run-20240326_220038-azkghiwm</code>
# Syncing run <strong><a href='https://wandb.ai/adaruna3/cmta3-classifier-maevit/runs/azkghiwm/workspace' target="_blank">exp_ni_maevit_classifier_l22_uscont</a></strong> to <a href='https://wandb.ai/adaruna3/cmta3-classifier-maevit' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/adaruna3/cmta3-classifier-maevit' target="_blank">https://wandb.ai/adaruna3/cmta3-classifier-maevit</a>
#  View run at <a href='https://wandb.ai/adaruna3/cmta3-classifier-maevit/runs/azkghiwm/workspace' target="_blank">https://wandb.ai/adaruna3/cmta3-classifier-maevit/runs/azkghiwm/workspace</a>
# Using 16bit None Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1.0)` was configured so 100% of the batches per epoch will be used..
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_test_batches=1.0)` was configured so 100% of the batches will be used..
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Predicting: 0it [00:00, ?it/s]
# VBox(children=(Label(value='0.031 MB of 0.031 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">exp_ni_maevit_classifier_l22_uscont</strong> at: <a href='https://wandb.ai/adaruna3/cmta3-classifier-maevit/runs/azkghiwm/workspace' target="_blank">https://wandb.ai/adaruna3/cmta3-classifier-maevit/runs/azkghiwm/workspace</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>../../logs/cmta3-classifier-maevit/runs/2024-03-26_21-49-14/wandb/run-20240326_220038-azkghiwm/logs</code>

# %% [markdown]
# Optionally, we can directly plot these produced maps. For example, below we plot the likelihood. Note - the raw output maps should be re-clipped using the study region bounds (e.g. a vector file) in QGIS.

# %%
import rasterio
# %matplotlib inline
import matplotlib.pyplot as plt
from pathlib import Path

with rasterio.open(maniac_maps[0], "r") as likelihood_raster:
    likelihood_data = likelihood_raster.read(1)
plt.imshow(likelihood_data, cmap="turbo")
plt.colorbar()
plt.show()
